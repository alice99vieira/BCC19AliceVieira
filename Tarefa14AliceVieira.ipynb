# %% [markdown]
# <a href="https://colab.research.google.com/github/alice99vieira/BCC19AliceVieira/blob/main/Tarefa14AliceVieira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Alice Vieira

# %% [markdown]
# 1) Para este item você deverá usar o arquivo com dados de força e torque medidos no chão enquanto uma pessoa tenta ficar em pé durante um minuto.
#
# Faça o gráfico do torque na direção y (My [Nm]) em função do tempo (Time [s]).

# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %%
B = pd.read_csv('https://raw.githubusercontent.com/alice99vieira/BasesComputacionais/bacd478ebcde398e853ef5c700168b98f105d3a3/aula7/dados/balance.csv')

# %%
plt.figure(figsize=(14, 7))
plt.plot(B['Time[s]'], B['My[Nm]'], color = 'red')
plt.grid()
plt.xlabel('tempo (Time [s])')
plt.ylabel('torque na direção y (My [Nm])')
plt.show()

# %% [markdown]
# Mostre na tela a média e o desvio-padrão do torque na direção y.

# %%
np.mean(B['My[Nm]'])

# %%
B['My[Nm]'].std()
# Out:
# 1.9778991737555645

# %% [markdown]
# 2) Para este item você deverá usar o arquivo com a taxa de inflação mensal (IGP-DI) no Brasil de fevereiro de 1944 a junho de 2019 (dados disponibilizados por Ipeadata).

# %%
IM = pd.read_csv('https://raw.githubusercontent.com/alice99vieira/BasesComputacionais/bacd478ebcde398e853ef5c700168b98f105d3a3/aula7/dados/inflacaoMensal.csv')

# %%
Março = IM.query("Mês == 3")
Março
# Out:
#       Ano  Mês  Inflação
# 1    1944    3      1.43
# 13   1945    3     -1.19
# 25   1946    3      1.09
# 37   1947    3      0.87
# 49   1948    3      1.68
# ..    ...  ...       ...
# 853  2015    3      1.21
# 865  2016    3      0.43
# 877  2017    3     -0.38
# 889  2018    3      0.56
# 901  2019    3      1.07
#
# [76 rows x 3 columns]

# %% [markdown]
# Calcule a mediana da inflação mensal nos meses de março.

# %%
mediana = Março ['Inflação'].median()
print(mediana)
# Out:
# 1.565

# %% [markdown]
# Calcule a média da inflação mensal nos meses de março.

# %%
media = Março['Inflação'].mean()
print(media)
# Out:
# 4.852631578947369

# %% [markdown]
# Calcule o desvio-padrão da inflação mensal nos meses de março.

# %%
Março['Inflação'].std()
# Out:
# 11.263066884695428

# %% [markdown]
# Faça o histograma da inflação mensal nos meses de março.

# %%
plt.figure()
Março['Inflação'].hist()
plt.xlabel('Inflação')
plt.show()

# %% [markdown]
# 3) Para este item você deverá usar o arquivo com a taxa de inflação mensal (IGP-DI) no Brasil de fevereiro de 1944 a junho de 2019 (dados disponibilizados por Ipeadata).

# %%
IM = pd.read_csv('https://raw.githubusercontent.com/alice99vieira/BasesComputacionais/bacd478ebcde398e853ef5c700168b98f105d3a3/aula7/dados/inflacaoMensal.csv')
M1995 = IM.query("Mês == 3 and Ano >= 1995")
M1995
# Out:
#       Ano  Mês  Inflação
# 613  1995    3      1.81
# 625  1996    3      0.22
# 637  1997    3      1.16
# 649  1998    3      0.23
# 661  1999    3      1.98
# 673  2000    3      0.18
# 685  2001    3      0.80
# 697  2002    3      0.11
# 709  2003    3      1.66
# 721  2004    3      0.93
# 733  2005    3      0.99
# 745  2006    3     -0.45
# 757  2007    3      0.22
# 769  2008    3      0.70
# 781  2009    3     -0.84
# 793  2010    3      0.63
# 805  2011    3      0.61
# 817  2012    3      0.56
# 829  2013    3      0.31
# 841  2014    3      1.48
# 853  2015    3      1.21
# 865  2016    3      0.43
# 877  2017    3     -0.38
# 889  2018    3      0.56
# 901  2019    3      1.07

# %% [markdown]
# Calcule a mediana da inflação mensal nos meses de março a partir de 1995.

# %%
mediana = M1995['Inflação'].median()
print(mediana)
# Out:
# 0.61

# %% [markdown]
# Calcule a média da inflação mensal nos meses de março a partir de 1995.

# %%
media = M1995['Inflação'].mean()
print(media)
# Out:
# 0.6472

# %% [markdown]
# Calcule o desvio-padrão da inflação mensal nos meses de março a partir de 1995.

# %%
M1995['Inflação'].std()
# Out:
# 0.6929497336267135

# %% [markdown]
# Faça o histograma da inflação mensal nos meses de março a partir de 1995.

# %%
plt.figure()
M1995['Inflação'].hist()
plt.xlabel('Inflação')
plt.show()

# %% [markdown]
# Coloque um comentário no seu script comentando a razão da diferença entre a média e a mediana ser alta no segundo item e baixa no terceiro item.

# %% [markdown]
# A razão pela qual a média e a mediana são altas no segundo caso e baixas no terceiro ocorre pelo fato de que a média utiliza todos os valores da inflação e divide pela quantidade de valores, quando retiramos alguns valores, a média não será a mesma. Em relação a mediana, é utilizado o valor central de um conjunto, quando tiramos os valores iniciais, vai se alterar também.

# %% [markdown]
# 4) Use a sequência de instruções abaixo para gerar N números aleatórios entre 0 e 1.
#
# rng = np.random.default_rng()
# x = rng.uniform(size=N)
#
# Faça o histograma e calcule (e mostre na tela) a média dos valores gerados.
#
# Faça isso para a) N = 100, N = 1000, c) N = 10000, d) N = 100000

# %% [markdown]
# a) N = 100
